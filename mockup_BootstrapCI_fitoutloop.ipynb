# %% [markdown]
# # import lib drive and load data mock up

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
df0 = pd.read_csv("/content/drive/MyDrive/com7_cradit_scoring/Ai monitoring/mock_y_pred_mZero.csv")
df1 = pd.read_csv("/content/drive/MyDrive/com7_cradit_scoring/Ai monitoring/mock_y_pred_m1.csv")
df2 = pd.read_csv("/content/drive/MyDrive/com7_cradit_scoring/Ai monitoring/mock_y_pred_m2.csv")
df_mock_demo = pd.read_csv("/content/drive/MyDrive/com7_cradit_scoring/Ai monitoring/demo_classification_mock.data.csv")

# %%
df2["0"].head()
# Out:
# 0    0.557630
# 1    0.509010
# 2    0.565759
# 3    0.647003
# 4    0.628223
# Name: 0, dtype: float64

# %%
df0.drop('Unnamed: 0', axis=1, inplace = np.True_)
df1.drop('Unnamed: 0', axis=1, inplace = np.True_)
df2.drop('Unnamed: 0', axis=1, inplace = np.True_)

# %%
df0 # month zero (deployment month)
# Out:
#              0
# 0     0.389579
# 1     0.345097
# 2     0.355435
# 3     0.353843
# 4     0.255176
# ...        ...
# 9995  0.129192
# 9996  0.444158
# 9997  0.368024
# 9998  0.507289
# 9999  0.443057
#
# [10000 rows x 1 columns]

# %% [markdown]
# # Confident interval with month zero (refference deployment month)

# %%
# import scipy.stats as st

# %%
df0['0']
# Out:
# 0       0.389579
# 1       0.345097
# 2       0.355435
# 3       0.353843
# 4       0.255176
#           ...
# 9995    0.129192
# 9996    0.444158
# 9997    0.368024
# 9998    0.507289
# 9999    0.443057
# Name: 0, Length: 10000, dtype: float64

# %%
data  = list(df0['0'])

# create 95% confidence interval
low_bon = np.quantile(data, 0.025)
high_bon = np.quantile(data, 0.975)
print("95% interval from {} to {}".format(low_bon,high_bon))
# Out:
# 95% interval from 0.11406714178877335 to 0.49752131663964155

# %%
low_bon/high_bon
# Out:
# 0.2292708633254262

# %%
plt.hist(data, bins=100)
plt.axvline(x=low_bon, color='green', linestyle=':')
plt.axvline(x=high_bon, color='green', linestyle=':')

# %% [markdown]
# # M0 (self) Bootstrap Confident interval at y only
# Next, we will configure the bootstrap. We will use 1,000 bootstrap iterations and select a sample that is 50% the size of the dataset.
#
# modified from method done in x feature

# %%
# configure bootstrap

n_iterations = 1000
n_size = int(len(data) * 0.50)

# %%
n_size
# Out:
# 5000

# %%
len(data)
# Out:
# 10000

# %% [markdown]
# # from dataset

# %%
import numpy
from pandas import read_csv
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from matplotlib import pyplot

# %%
df_mock_demo.values.shape
# Out:
# (767, 9)

# %%
int(len(df_mock_demo)*0.5)
# Out:
# 383

# %%
resample(df_mock_demo.values, n_samples=383).shape
# Out:
# (383, 9)

# %%
numpy.array([x for x in df_mock_demo.values]).shape
# Out:
# (767, 9)

# %% [markdown]
# resample bootstrap x for n loop and concat to be bigger dataset x with labels

# %%
values = df_mock_demo.values

# configure bootstrap
n_iterations = 1000
n_size = int(len(df_mock_demo) * 0.50)

# run bootstrap
Concat_BS_dataset = values.copy()
for i in range(n_iterations):
	# prepare bootstrap dataset and concat
	BS_set = resample(values, n_samples=n_size)
	Concat_BS_dataset = numpy.concatenate((Concat_BS_dataset, BS_set), axis= 0)

# %%
print("After concate row should be : ",767+(383*10000))
print("shape after bootstrap : ",Concat_BS_dataset.shape)
# Out:
# After concate row should be :  3830767
# shape after bootstrap :  (383767, 9)

# %% [markdown]
# check shape and column prior split to train and test

# %%
print(Concat_BS_dataset[:,:-1].shape)
print(Concat_BS_dataset[:1])
# Out:
# (383767, 8)
# [[ 1.    85.    66.    29.     0.    26.6    0.351 31.     0.   ]]

# %% [markdown]
# test set have to split out from new dataset (concatenated dataset)

# %%
# prepare train and test sets
X_train, X_test, y_train, y_test = train_test_split(Concat_BS_dataset[:,:-1], Concat_BS_dataset[:,-1], test_size=0.33, stratify=Concat_BS_dataset[:,-1] ,random_state=40)

# %%
y_train.shape
# Out:
# (257123,)

# %%
# fit model
from sklearn.linear_model import LogisticRegression
# model = DecisionTreeClassifier()
model = LogisticRegression(random_state=0)
model.fit(X_train, y_train)

# evaluate model
predictions = model.predict(X_test)
score = accuracy_score(y_test, predictions)
print(score)
# Out:
# 0.7862670162028995
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#fit in loop
values = df_mock_demo.values

# configure bootstrap
n_iterations = 1000
n_size = int(len(df_mock_demo) * 0.50)
# run bootstrap
stats = list()
for i in range(n_iterations):
	# prepare train and test sets
	train = resample(values, n_samples=n_size)
	test = numpy.array([x for x in values if x.tolist() not in train.tolist()])
	# fit model
	model = DecisionTreeClassifier()
	model.fit(train[:,:-1], train[:,-1])
	# evaluate model
	predictions = model.predict(test[:,:-1])
	score = accuracy_score(test[:,-1], predictions)
	print(score)
	stats.append(score)

# %% [markdown]
# here we can **change score to do bootstrap to be other metric** apart from accurcy such as F1 score , or recal, or AUC

# %% [markdown]
# When we got Month 1 and event rate on month 1 we also can compare Confident interval and define threshold to decide for recalibrate or redevelop as well

# %%
len(stats) # list
# Out:
# 1000

# %%
stats1 = [1-x for x in stats ]
stats1

# %% [markdown]
# ## month0 bootstrap confidence interval

# %%
# confidence intervals
alpha = 0.95
p = ((1.0-alpha)/2.0) * 100
lower = max(0.0, numpy.percentile(stats1, p))
p = (alpha+((1.0-alpha)/2.0)) * 100
upper = min(1.0, numpy.percentile(stats1, p))
print('%.1f confidence interval %.1f%% and %.1f%%' % (alpha*100, lower*100, upper*100))

# plot scores
pyplot.hist(stats1)
plt.axvline(x=lower, color='green', linestyle='--')
plt.axvline(x=upper, color='green', linestyle='--')
pyplot.show()
# Out:
# 95.0 confidence interval 27.0% and 35.6%

# %%
(27+35.6)/2
# Out:
# 31.3

# %% [markdown]
# # trial fuction sim drift dataset
# bootstrap have to train and see at score from iteration bootstrapping.
# <br>The idea is :<br>
# So we simulate just assume that we use same model but actually use little bit bad model to simulate drifting on prediction

# %%
import numpy
from pandas import read_csv
from sklearn.utils import resample
# from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from matplotlib import pyplot
# load dataset
# data = read_csv('data.csv', header=None)

values = df_mock_demo.values
# configure bootstrap
n_iterations = 1000
n_size = int(len(df_mock_demo) * 0.50)
# run bootstrap
stats2 = list()
for i in range(n_iterations):
	# prepare train and test sets
	train = resample(values, n_samples=n_size)
	test = numpy.array([x for x in values if x.tolist() not in train.tolist()])
	# fit model
	model = LogisticRegression(random_state=0)
	model.fit(train[:,:-1], train[:,-1])
	# evaluate model
	predictions = model.predict(test[:,:-1])
	score = accuracy_score(test[:,-1], predictions)
	print(score)
	stats2.append(score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7553648068669528
# 0.75
# 0.7782515991471215
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7803837953091685
# 0.774468085106383
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7531380753138075
# 0.7855579868708972
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7282377919320594
# 0.7720430107526882
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7647058823529411
# 0.7516339869281046
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7580299785867237
# 0.7632135306553911
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7613882863340564
# 0.733615221987315
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.748898678414097
# 0.7440860215053764
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7452229299363057
# 0.7424892703862661
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7659574468085106
# 0.7521008403361344
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7636761487964989
# 0.7751091703056768
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7825159914712153
# 0.7396963123644251
# 0.7564655172413793
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.778969957081545
# 0.7510638297872341
# 0.759493670886076
# 0.7650862068965517
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7372881355932204
# 0.732776617954071
# 0.7549234135667396
# 0.7749469214437368
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7818574514038877
# 0.7901498929336188
# 0.7629310344827587
# 0.7611940298507462
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.783157894736842
# 0.75
# 0.7794759825327511
# 0.7732181425485961
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7505197505197505
# 0.7505376344086021
# 0.7672413793103449
# 0.7610993657505285
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7894736842105263
# 0.740506329113924
# 0.7673913043478261
# 0.7521739130434782
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7483870967741936
# 0.7350427350427351
# 0.7613882863340564
# 0.759656652360515
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7604395604395604
# 0.7608695652173914
# 0.7341772151898734
# 0.772823779193206
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7690677966101694
# 0.7584033613445378
# 0.7543478260869565
# 0.7617021276595745
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7570498915401301
# 0.7392241379310345
# 0.7620087336244541
# 0.7526881720430108
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7473233404710921
# 0.7543103448275862
# 0.7478448275862069
# 0.7652173913043478
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7456521739130435
# 0.7690677966101694
# 0.75764192139738
# 0.7414529914529915
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7551440329218106
# 0.7435897435897436
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7473233404710921
# 0.7665198237885462
# 0.7678958785249458
# 0.7434782608695653
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.76
# 0.7575107296137339
# 0.7939262472885033
# 0.7399577167019028
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7272727272727273
# 0.7397849462365591
# 0.7622080679405521
# 0.7558386411889597
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.723175965665236
# 0.7293868921775899
# 0.7389380530973452
# 0.7371794871794872
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7467811158798283
# 0.7849462365591398
# 0.7838427947598253
# 0.7580993520518359
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7780172413793104
# 0.7526881720430108
# 0.7690631808278867
# 0.7698924731182796
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7645833333333333
# 0.7577092511013216
# 0.7444933920704846
# 0.7617021276595745
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7760869565217391
# 0.7721518987341772
# 0.790948275862069
# 0.7667386609071274
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7425531914893617
# 0.7868131868131868
# 0.7858672376873662
# 0.758985200845666
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7748917748917749
# 0.7569296375266524
# 0.7832618025751072
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7554112554112554
# 0.7483588621444202
# 0.7542735042735043
# 0.7505285412262156
# 0.7708779443254818
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
stats2_re = [1-x for x in stats2 ]

# %%
stats2_re
# Out:
# [0.24463519313304716,
#  0.25,
#  0.2217484008528785,
#  0.21961620469083154,
#  0.225531914893617,
#  0.2468619246861925,
#  0.21444201312910283,
#  0.2717622080679406,
#  0.22795698924731178,
#  0.23529411764705888,
#  0.24836601307189543,
#  0.24197002141327628,
#  0.2367864693446089,
#  0.23861171366594358,
#  0.266384778012685,
#  0.25110132158590304,
#  0.2559139784946236,
#  0.2547770700636943,
#  0.2575107296137339,
#  0.23404255319148937,
#  0.24789915966386555,
#  0.23632385120350108,
#  0.22489082969432317,
#  0.2174840085287847,
#  0.2603036876355749,
#  0.24353448275862066,
#  0.22103004291845496,
#  0.24893617021276593,
#  0.240506329113924,
#  0.2349137931034483,
#  0.2627118644067796,
#  0.267223382045929,
#  0.24507658643326036,
#  0.22505307855626322,
#  0.21814254859611226,
#  0.2098501070663812,
#  0.23706896551724133,
#  0.23880597014925375,
#  0.21684210526315795,
#  0.25,
#  0.22052401746724892,
#  0.2267818574514039,
#  0.2494802494802495,
#  0.2494623655913979,
#  0.23275862068965514,
#  0.2389006342494715,
#  0.21052631578947367,
#  0.259493670886076,
#  0.2326086956521739,
#  0.24782608695652175,
#  0.25161290322580643,
#  0.2649572649572649,
#  0.23861171366594358,
#  0.24034334763948495,
#  0.2395604395604396,
#  0.23913043478260865,
#  0.26582278481012656,
#  0.227176220806794,
#  0.23093220338983056,
#  0.24159663865546221,
#  0.2456521739130435,
#  0.23829787234042554,
#  0.24295010845986986,
#  0.2607758620689655,
#  0.2379912663755459,
#  0.24731182795698925,
#  0.25267665952890794,
#  0.2456896551724138,
#  0.25215517241379315,
#  0.23478260869565215,
#  0.2543478260869565,
#  0.23093220338983056,
#  0.24235807860262004,
#  0.2585470085470085,
#  0.24485596707818935,
#  0.2564102564102564,
#  0.25267665952890794,
#  0.23348017621145378,
#  0.23210412147505421,
#  0.25652173913043474,
#  0.24,
#  0.2424892703862661,
#  0.20607375271149675,
#  0.2600422832980972,
#  0.2727272727272727,
#  0.2602150537634409,
#  0.23779193205944793,
#  0.24416135881104029,
#  0.21615720524017468,
#  0.23982869379014993,
#  0.23454157782515994,
#  0.26694915254237284,
#  0.28205128205128205,
#  0.22838137472283815,
#  0.2436440677966102,
#  0.1961620469083155,
#  0.23529411764705888,
#  0.2636165577342048,
#  0.2527233115468409,
#  0.2286902286902287,
#  0.2270833333333333,
#  0.24406047516198703,
#  0.25215517241379315,
#  0.24728850325379614,
#  0.2585470085470085,
#  0.21638655462184875,
#  0.22838137472283815,
#  0.2145922746781116,
#  0.2436440677966102,
#  0.23982869379014993,
#  0.2381974248927039,
#  0.20390455531453366,
#  0.24406047516198703,
#  0.259958071278826,
#  0.23554603854389722,
#  0.22030237580993517,
#  0.2451612903225806,
#  0.22851153039832284,
#  0.2184154175588865,
#  0.2435897435897436,
#  0.21336206896551724,
#  0.23580786026200873,
#  0.23554603854389722,
#  0.2226980728051392,
#  0.2424892703862661,
#  0.24786324786324787,
#  0.2021505376344086,
#  0.24683544303797467,
#  0.27450980392156865,
#  0.240506329113924,
#  0.2286324786324786,
#  0.2467248908296943,
#  0.22993492407809113,
#  0.25164113785557984,
#  0.2292993630573248,
#  0.23991507430997872,
#  0.2633832976445396,
#  0.28,
#  0.24145299145299148,
#  0.2431289640591966,
#  0.2542372881355932,
#  0.25965665236051505,
#  0.25366876310272535,
#  0.22197802197802197,
#  0.22587719298245612,
#  0.2603938730853391,
#  0.25442477876106195,
#  0.2515991471215352,
#  0.23809523809523814,
#  0.2532751091703057,
#  0.23191489361702122,
#  0.2226980728051392,
#  0.2548179871520343,
#  0.22995780590717296,
#  0.2175824175824176,
#  0.2548179871520343,
#  0.24017467248908297,
#  0.2616033755274262,
#  0.2420382165605095,
#  0.24678111587982832,
#  0.24731182795698925,
#  0.27450980392156865,
#  0.2195652173913043,
#  0.26681127982646424,
#  0.24034334763948495,
#  0.23728813559322037,
#  0.25053995680345575,
#  0.24416135881104029,
#  0.2478070175438597,
#  0.2282608695652174,
#  0.2332613390928726,
#  0.2620087336244541,
#  0.23390557939914158,
#  0.225531914893617,
#  0.23605150214592274,
#  0.2549450549450549,
#  0.25701943844492436,
#  0.2142857142857143,
#  0.24782608695652175,
#  0.2381974248927039,
#  0.24557522123893805,
#  0.24025974025974028,
#  0.23655913978494625,
#  0.2367864693446089,
#  0.22814498933901917,
#  0.259493670886076,
#  0.2817796610169492,
#  0.2559139784946236,
#  0.23027718550106613,
#  0.296137339055794,
#  0.2326086956521739,
#  0.2666666666666667,
#  0.26819126819126815,
#  0.24472573839662448,
#  0.20905172413793105,
#  0.22912205567451815,
#  0.24034334763948495,
#  0.2505353319057816,
#  0.22795698924731178,
#  0.25,
#  0.23454157782515994,
#  0.2494623655913979,
#  0.2574468085106383,
#  0.23043478260869565,
#  0.2452431289640592,
#  0.2188841201716738,
#  0.26539278131634825,
#  0.2618025751072961,
#  0.2692307692307693,
#  0.24520255863539442,
#  0.22993492407809113,
#  0.2591006423982869,
#  0.2537960954446855,
#  0.25263157894736843,
#  0.2142857142857143,
#  0.23593073593073588,
#  0.23861171366594358,
#  0.258695652173913,
#  0.28165938864628826,
#  0.25053995680345575,
#  0.25215517241379315,
#  0.23717948717948723,
#  0.21212121212121215,
#  0.27489177489177485,
#  0.25,
#  0.2226980728051392,
#  0.22368421052631582,
#  0.20915032679738566,
#  0.20833333333333337,
#  0.2467248908296943,
#  0.21702127659574466,
#  0.28936170212765955,
#  0.23908523908523904,
#  0.2489539748953975,
#  0.2272727272727273,
#  0.23362445414847166,
#  0.22457627118644063,
#  0.2236559139784946,
#  0.2494623655913979,
#  0.2575107296137339,
#  0.24728850325379614,
#  0.21382289416846656,
#  0.21794871794871795,
#  0.24507658643326036,
#  0.2375809935205183,
#  0.2760084925690022,
#  0.24683544303797467,
#  0.22844827586206895,
#  0.2275711159737418,
#  0.2195652173913043,
#  0.23789473684210527,
#  0.23841059602649006,
#  0.2349137931034483,
#  0.2521186440677966,
#  0.2585470085470085,
#  0.22055674518201285,
#  0.2226890756302521,
#  0.2592592592592593,
#  0.24152542372881358,
#  0.24369747899159666,
#  0.26681127982646424,
#  0.23376623376623373,
#  0.23542116630669552,
#  0.25106382978723407,
#  0.24572649572649574,
#  0.23464912280701755,
#  0.22245762711864403,
#  0.23554603854389722,
#  0.2536082474226804,
#  0.23655913978494625,
#  0.24669603524229078,
#  0.2536997885835095,
#  0.2424892703862661,
#  0.23010752688172043,
#  0.23931623931623935,
#  0.25053995680345575,
#  0.24347826086956526,
#  0.2191489361702128,
#  0.25,
#  0.22466960352422904,
#  0.22746781115879833,
#  0.23225806451612907,
#  0.23922413793103448,
#  0.20869565217391306,
#  0.2422907488986784,
#  0.2633832976445396,
#  0.21908893709327548,
#  0.22765957446808516,
#  0.2702127659574468,
#  0.23275862068965514,
#  0.22462203023758098,
#  0.2577092511013216,
#  0.26824034334763946,
#  0.24421052631578943,
#  0.2186147186147186,
#  0.2581344902386117,
#  0.25917926565874727,
#  0.22795698924731178,
#  0.2171052631578947,
#  0.2421052631578947,
#  0.2257383966244726,
#  0.2349137931034483,
#  0.24078091106290678,
#  0.26050420168067223,
#  0.24353448275862066,
#  0.2215189873417721,
#  0.2368972746331237,
#  0.2527233115468409,
#  0.24838012958963285,
#  0.2364425162689805,
#  0.2292993630573248,
#  0.23175965665236054,
#  0.2200435729847494,
#  0.2349137931034483,
#  0.2098501070663812,
#  0.24628450106157107,
#  0.240506329113924,
#  0.30869565217391304,
#  0.22532188841201717,
#  0.22055674518201285,
#  0.2590233545647559,
#  0.25053078556263275,
#  0.23946784922394682,
#  0.24782608695652175,
#  0.22784810126582278,
#  0.23861171366594358,
#  0.2547770700636943,
#  0.3121019108280255,
#  0.24137931034482762,
#  0.25806451612903225,
#  0.24347826086956526,
#  0.27391304347826084,
#  0.23931623931623935,
#  0.22961373390557938,
#  0.24034334763948495,
#  0.23290598290598286,
#  0.2349137931034483,
#  0.26526315789473687,
#  0.2451612903225806,
#  0.26881720430107525,
#  0.22150537634408607,
#  0.2168141592920354,
#  0.23982869379014993,
#  0.2489539748953975,
#  0.25427350427350426,
#  0.26315789473684215,
#  0.22532188841201717,
#  0.23311546840958608,
#  0.24628450106157107,
#  0.2139737991266376,
#  0.2510729613733905,
#  0.22532188841201717,
#  0.22077922077922074,
#  0.2395604395604396,
#  0.24061810154525387,
#  0.22055674518201285,
#  0.26980728051391867,
#  0.23788546255506604,
#  0.2344086021505376,
#  0.2620087336244541,
#  0.24615384615384617,
#  0.24511930585683295,
#  0.2607758620689655,
#  0.2231578947368421,
#  0.2489539748953975,
#  0.2236559139784946,
#  0.24458874458874458,
#  0.2395604395604396,
#  0.22616407982261644,
#  0.2287581699346405,
#  0.22844827586206895,
#  0.2817796610169492,
#  0.2733188720173536,
#  0.25164113785557984,
#  0.21794871794871795,
#  0.2547770700636943,
#  0.25,
#  0.2564102564102564,
#  0.24411134903640253,
#  0.2634989200863931,
#  0.2085106382978723,
#  0.25531914893617025,
#  0.24892703862660948,
#  0.2776572668112798,
#  0.2494623655913979,
#  0.2349137931034483,
#  0.23210412147505421,
#  0.24217118997912312,
#  0.23376623376623373,
#  0.2838983050847458,
#  0.24301075268817207,
#  0.22150537634408607,
#  0.25215517241379315,
#  0.21638655462184875,
#  0.24034334763948495,
#  0.2375809935205183,
#  0.2555066079295154,
#  0.2532467532467533,
#  0.22052401746724892,
#  0.2549450549450549,
#  0.25536480686695284,
#  0.23542116630669552,
#  0.2537960954446855,
#  0.2537634408602151,
#  0.2316017316017316,
#  0.22736842105263155,
#  0.22008547008547008,
#  0.24122807017543857,
#  0.2559652928416486,
#  0.23809523809523814,
#  0.2444933920704846,
#  0.22993492407809113,
#  0.20607375271149675,
#  0.25215517241379315,
#  0.2549019607843137,
#  0.25917926565874727,
#  0.2149122807017544,
#  0.24458874458874458,
#  0.26419213973799127,
#  0.19912472647702406,
#  0.24843423799582465,
#  0.24137931034482762,
#  0.2186147186147186,
#  0.276824034334764,
#  0.24411134903640253,
#  0.23829787234042554,
#  0.25646551724137934,
#  0.22489082969432317,
#  0.2350427350427351,
#  0.21350762527233114,
#  0.2289416846652268,
#  0.26898047722342733,
#  0.255863539445629,
#  0.21767241379310343,
#  0.2311015118790497,
#  0.23290598290598286,
#  0.2286324786324786,
#  0.2369565217391304,
#  0.2097457627118644,
#  0.24282560706401768,
#  0.25531914893617025,
#  0.24507658643326036,
#  0.24190064794816413,
#  0.23191489361702122,
#  0.241304347826087,
#  0.2297592997811816,
#  0.2948717948717948,
#  0.21244635193133043,
#  0.2265795206971678,
#  0.23390557939914158,
#  0.26048565121412803,
#  0.23829787234042554,
#  0.21999999999999997,
#  0.2342733188720173,
#  0.2823275862068966,
#  0.2558139534883721,
#  0.23093220338983056,
#  0.22814498933901917,
#  0.2272727272727273,
#  0.2494623655913979,
#  0.2222222222222222,
#  0.23093681917211328,
#  0.2628205128205128,
#  0.2569002123142251,
#  0.20995670995671,
#  0.25799573560767586,
#  0.23739495798319332,
#  0.2283298097251586,
#  0.19873150105708248,
#  0.2381974248927039,
#  0.241304347826087,
#  0.23706896551724133,
#  0.24520255863539442,
#  0.2068230277185501,
#  0.22807017543859653,
#  0.22388059701492535,
#  0.2169197396963124,
#  0.24217118997912312,
#  0.21333333333333337,
#  0.2537634408602151,
#  0.20299145299145294,
#  0.23931623931623935,
#  0.2210065645514223,
#  0.23076923076923073,
#  0.2516268980477223,
#  0.2574468085106383,
#  0.23284823284823286,
#  0.24839400428265523,
#  0.2169197396963124,
#  0.2537960954446855,
#  0.276824034334764,
#  0.24416135881104029,
#  0.24625267665952888,
#  0.21935483870967742,
#  0.24145299145299148,
#  0.24786324786324787,
#  0.25,
#  0.2217294900221729,
#  0.23142250530785557,
#  0.2191489361702128,
#  0.2647702407002188,
#  0.2056277056277056,
#  0.2552742616033755,
#  0.22601279317697232,
#  0.25108225108225113,
#  0.24731182795698925,
#  0.23554603854389722,
#  0.2344086021505376,
#  0.2505446623093682,
#  0.24159663865546221,
#  0.241304347826087,
#  0.23109243697478987,
#  0.2417582417582418,
#  0.223175965665236,
#  0.21935483870967742,
#  0.22103004291845496,
#  0.2780172413793104,
#  0.234375,
#  0.24406047516198703,
#  0.2542372881355932,
#  0.21673819742489275,
#  0.23451327433628322,
#  0.23275862068965514,
#  0.22150537634408607,
#  0.25917926565874727,
#  0.23240938166311298,
#  0.2267818574514039,
#  0.23109243697478987,
#  0.24416135881104029,
#  0.21814254859611226,
#  0.22345132743362828,
#  0.23076923076923073,
#  0.26050420168067223,
#  0.23417721518987344,
#  0.2468619246861925,
#  0.23922413793103448,
#  0.2219827586206896,
#  0.2537634408602151,
#  0.22961373390557938,
#  0.24034334763948495,
#  0.24472573839662448,
#  0.2633832976445396,
#  0.21382289416846656,
#  0.2259414225941423,
#  0.28051391862955033,
#  0.27408993576017127,
#  0.24731182795698925,
#  0.23311546840958608,
#  0.2591006423982869,
#  0.22173913043478266,
#  0.2226980728051392,
#  0.2292993630573248,
#  0.2543478260869565,
#  0.24572649572649574,
#  0.2579281183932347,
#  0.21308016877637126,
#  0.2717391304347826,
#  0.21894736842105267,
#  0.2287581699346405,
#  0.2750533049040512,
#  0.24034334763948495,
#  0.21802935010482183,
#  0.2287581699346405,
#  0.2389006342494715,
#  0.24137931034482762,
#  0.23478260869565215,
#  0.2387096774193549,
#  0.26539278131634825,
#  0.21535181236673773,
#  0.23605150214592274,
#  0.24625267665952888,
#  0.2417582417582418,
#  0.2272727272727273,
#  0.2557651991614256,
#  0.25267665952890794,
#  0.23311546840958608,
#  0.23478260869565215,
#  0.22483940042826556,
#  0.25701943844492436,
#  0.2226890756302521,
#  0.20086393088552912,
#  0.2543478260869565,
#  0.2346723044397463,
#  0.23275862068965514,
#  0.22580645161290325,
#  0.24836601307189543,
#  0.26980728051391867,
#  0.23655913978494625,
#  0.22478991596638653,
#  0.2760869565217391,
#  0.24726477024070026,
#  0.2532188841201717,
#  0.23851203501094087,
#  0.22388059701492535,
#  0.23880597014925375,
#  0.22844827586206895,
#  0.22787610619469023,
#  0.24511930585683295,
#  0.21656050955414008,
#  0.24945770065075923,
#  0.22669491525423724,
#  0.2591006423982869,
#  0.222707423580786,
#  0.2129032258064516,
#  0.2505353319057816,
#  0.2420382165605095,
#  0.23684210526315785,
#  0.2387096774193549,
#  0.2198731501057083,
#  0.20131291028446385,
#  0.23655913978494625,
#  0.22103004291845496,
#  0.2585470085470085,
#  0.20950323974082075,
#  0.255863539445629,
#  0.23542116630669552,
#  0.2409381663113006,
#  0.20852017937219736,
#  0.2405857740585774,
#  0.24784482758620685,
#  0.2375809935205183,
#  0.2186147186147186,
#  0.21108742004264391,
#  0.26315789473684215,
#  0.2387096774193549,
#  0.2369565217391304,
#  0.2177589852008457,
#  0.24347826086956526,
#  0.19496855345911945,
#  0.23010752688172043,
#  0.27233115468409586,
#  0.23454157782515994,
#  0.24728850325379614,
#  0.23076923076923073,
#  0.2543103448275862,
#  0.2350427350427351,
#  0.2426778242677824,
#  0.21881838074398252,
#  0.22616407982261644,
#  0.21108742004264391,
#  0.24678111587982832,
#  0.2773109243697479,
#  0.2379912663755459,
#  0.24731182795698925,
#  0.22127659574468084,
#  0.24836601307189543,
#  0.23290598290598286,
#  0.20905172413793105,
#  0.2435897435897436,
#  0.22246696035242286,
#  0.2420382165605095,
#  0.22993492407809113,
#  0.24631578947368427,
#  0.26326963906581746,
#  0.22033898305084743,
#  0.23529411764705888,
#  0.25105485232067515,
#  0.21702127659574466,
#  0.273109243697479,
#  0.23593073593073588,
#  0.23376623376623373,
#  0.25514403292181065,
#  0.2085106382978723,
#  0.23903508771929827,
#  0.24145299145299148,
#  0.23178807947019864,
#  0.2364425162689805,
#  0.24840764331210186,
#  0.24520255863539442,
#  0.2585470085470085,
#  0.23580786026200873,
#  0.22807017543859653,
#  0.23931623931623935,
#  0.23175965665236054,
#  0.25701943844492436,
#  0.23175965665236054,
#  0.23717948717948723,
#  0.24472573839662448,
#  0.21179039301310043,
#  0.23368421052631583,
#  0.2801724137931034,
#  0.26521739130434785,
#  0.24468085106382975,
#  0.21581196581196582,
#  0.25427350427350426,
#  0.23010752688172043,
#  0.24890829694323147,
#  0.2515991471215352,
#  0.23290598290598286,
#  0.25053078556263275,
#  0.22580645161290325,
#  0.2516268980477223,
#  0.21868365180467086,
#  0.2301255230125523,
#  0.27234042553191484,
#  0.22342733188720176,
#  0.2283298097251586,
#  0.22150537634408607,
#  0.23982869379014993,
#  0.2781456953642384,
#  0.23390557939914158,
#  0.2366737739872068,
#  0.2505263157894737,
#  0.23478260869565215,
#  0.3049040511727079,
#  0.23111111111111116,
#  0.20302375809935203,
#  0.23965141612200436,
#  0.24468085106382975,
#  0.24342105263157898,
#  0.24678111587982832,
#  0.2262931034482759,
#  0.2350427350427351,
#  0.23779193205944793,
#  0.21673819742489275,
#  0.24894514767932485,
#  0.2169197396963124,
#  0.2564102564102564,
#  0.22532188841201717,
#  0.23390557939914158,
#  0.2673913043478261,
#  0.26236559139784943,
#  0.2214912280701754,
#  0.2387096774193549,
#  0.2467248908296943,
#  0.2326086956521739,
#  0.2807017543859649,
#  0.24406047516198703,
#  0.2153846153846154,
#  0.271948608137045,
#  0.23026315789473684,
#  0.1995708154506438,
#  0.2613390928725702,
#  0.23779193205944793,
#  0.25,
#  0.24631578947368427,
#  0.2222222222222222,
#  0.24197002141327628,
#  0.25263157894736843,
#  0.24034334763948495,
#  0.22993492407809113,
#  0.2316017316017316,
#  0.2231947483588621,
#  0.27813163481953296,
#  0.25427350427350426,
#  0.21940928270042193,
#  0.24945295404814005,
#  0.23851203501094087,
#  0.24369747899159666,
#  0.27311827956989243,
#  0.2626050420168067,
#  0.2432432432432432,
#  0.265658747300216,
#  0.2563559322033898,
#  0.23454157782515994,
#  0.23404255319148937,
#  0.21610169491525422,
#  0.22388059701492535,
#  0.23851203501094087,
#  0.22961373390557938,
#  0.2537634408602151,
#  0.28297872340425534,
#  0.2366737739872068,
#  0.2349137931034483,
#  0.25646551724137934,
#  0.21908893709327548,
#  0.23829787234042554,
#  0.2175732217573222,
#  0.20742358078602618,
#  0.2229437229437229,
#  0.24463519313304716,
#  0.2557651991614256,
#  0.222707423580786,
#  0.2409381663113006,
#  0.2603036876355749,
#  0.25,
#  0.23628691983122363,
#  0.2494714587737844,
#  0.26247288503253796,
#  0.2195652173913043,
#  0.2292993630573248,
#  0.2319474835886215,
#  0.2219827586206896,
#  0.2272727272727273,
#  0.23516483516483522,
#  0.24070021881838077,
#  0.24669603524229078,
#  0.20718816067653278,
#  0.24468085106382975,
#  0.2269807280513919,
#  0.2543478260869565,
#  0.23240938166311298,
#  0.24892703862660948,
#  0.26980728051391867,
#  0.29373650107991356,
#  0.2811158798283262,
#  0.2112068965517241,
#  0.27311827956989243,
#  0.22559652928416485,
#  0.25,
#  0.23010752688172043,
#  0.2364425162689805,
#  0.2381974248927039,
#  0.23717948717948723,
#  0.2585470085470085,
#  0.2214912280701754,
#  0.2554112554112554,
#  0.22246696035242286,
#  0.24183006535947715,
#  0.25215517241379315,
#  0.24086021505376343,
#  0.23175965665236054,
#  0.24137931034482762,
#  0.2620087336244541,
#  0.24628450106157107,
#  0.2267818574514039,
#  0.25799573560767586,
#  0.23311546840958608,
#  0.2142857142857143,
#  0.2586206896551724,
#  0.23768736616702357,
#  0.22489082969432317,
#  0.23027718550106613,
#  0.2515991471215352,
#  0.25965665236051505,
#  0.2505446623093682,
#  0.2306034482758621,
#  0.2543478260869565,
#  0.2145922746781116,
#  0.25210084033613445,
#  0.23542116630669552,
#  0.24789915966386555,
#  0.2188841201716738,
#  0.23899371069182385,
#  0.2826552462526767,
#  0.2531914893617021,
#  0.25110132158590304,
#  0.24889867841409696,
#  0.2585470085470085,
#  0.23093220338983056,
#  0.22580645161290325,
#  0.22899159663865543,
#  0.2283298097251586,
#  0.23829787234042554,
#  0.2236286919831224,
#  0.25161290322580643,
#  0.23789473684210527,
#  0.23191489361702122,
#  0.2375809935205183,
#  0.21166306695464365,
#  0.2548179871520343,
#  0.21673819742489275,
#  0.2229437229437229,
#  0.21645021645021645,
#  0.258695652173913,
#  0.2222222222222222,
#  0.25646551724137934,
#  0.25267665952890794,
#  0.2599118942731278,
#  0.23789473684210527,
#  0.2725321888412017,
#  0.22435897435897434,
#  0.23076923076923073,
#  0.2098501070663812,
#  0.25485961123110146,
#  0.24786324786324787,
#  0.23175965665236054,
#  0.24784482758620685,
#  0.25108225108225113,
#  0.22637362637362635,
#  0.22532188841201717,
#  0.2361702127659574,
#  0.24183006535947715,
#  0.22912205567451815,
#  0.25,
#  0.2364425162689805,
#  0.23210412147505421,
#  0.23516949152542377,
#  0.26269315673289184,
#  0.24197002141327628,
#  0.2742616033755274,
#  0.2286324786324786,
#  0.24678111587982832,
#  0.2515991471215352,
#  0.2603036876355749,
#  0.21321961620469088,
#  0.2597402597402597,
#  0.22961373390557938,
#  0.25274725274725274,
#  0.2322175732217573,
#  0.2332613390928726,
#  0.23922413793103448,
#  0.2350427350427351,
#  0.225531914893617,
#  0.259493670886076,
#  0.24628450106157107,
#  0.2155172413793104,
#  0.2593406593406593,
#  0.24737945492662472,
#  0.2592592592592593,
#  0.23554603854389722,
#  0.22292993630573243,
#  0.22844827586206895,
#  0.20824295010845983,
#  0.25764192139737996,
#  0.24784482758620685,
#  0.281183932346723,
#  0.22198731501057078,
#  0.21585903083700442,
#  0.24678111587982832,
#  0.2366737739872068,
#  0.24255319148936172,
#  0.22055674518201285,
#  0.2770562770562771,
#  0.22925764192139741,
#  0.2275574112734864,
#  0.24622030237580994,
#  0.23768736616702357,
#  0.27212389380530977,
#  0.23093220338983056,
#  0.21338912133891208,
#  0.2177589852008457,
#  0.23982869379014993,
#  0.25485961123110146,
#  0.23144104803493448,
#  0.2272727272727273,
#  0.2435897435897436,
#  0.2236559139784946,
#  0.2799145299145299,
#  0.2673913043478261,
#  0.21244635193133043,
#  0.23568281938325997,
#  0.22417582417582416,
#  0.3347547974413646,
#  0.20299145299145294,
#  0.23940677966101698,
#  0.23225806451612907,
#  0.21412803532008828,
#  0.2548179871520343,
#  0.25473684210526315,
#  0.25806451612903225,
#  0.24675324675324672,
#  0.2033898305084746,
#  0.2727272727272727,
#  0.22295805739514352,
#  0.25917926565874727,
#  0.2537634408602151,
#  0.2195652173913043,
#  0.23478260869565215,
#  0.24945770065075923,
#  0.22925764192139741,
#  0.2272727272727273,
#  0.24731182795698925,
#  0.20824295010845983,
#  0.2574468085106383,
#  0.22466960352422904,
#  0.24511930585683295,
#  0.22483940042826556,
#  0.25646551724137934,
#  0.21489361702127663,
#  0.2361702127659574,
#  0.24190064794816413,
#  0.2468085106382979,
#  0.2489539748953975,
#  0.23240938166311298,
#  0.23340471092077086,
#  0.22052401746724892,
#  0.23275862068965514,
#  0.276824034334764,
#  0.2706131078224101,
#  0.26106194690265483,
#  0.2628205128205128,
#  0.2532188841201717,
#  0.21505376344086025,
#  0.21615720524017468,
#  0.24190064794816413,
#  0.2219827586206896,
#  0.24731182795698925,
#  0.23093681917211328,
#  0.23010752688172043,
#  0.23541666666666672,
#  0.2422907488986784,
#  0.2555066079295154,
#  0.23829787234042554,
#  0.2239130434782609,
#  0.22784810126582278,
#  0.20905172413793105,
#  0.2332613390928726,
#  0.2574468085106383,
#  0.2131868131868132,
#  0.21413276231263378,
#  0.241014799154334,
#  0.22510822510822515,
#  0.24307036247334757,
#  0.21673819742489275,
#  0.24458874458874458,
#  0.25164113785557984,
#  0.24572649572649574,
#  0.2494714587737844,
#  0.22912205567451815]

# %% [markdown]
# ## month1 bootstrap confidence interval

# %%
# confidence intervals
alpha = 0.95
p = ((1.0-alpha)/2.0) * 100
lower = max(0.0, numpy.percentile(stats2_re, p))
p = (alpha+((1.0-alpha)/2.0)) * 100
upper = min(1.0, numpy.percentile(stats2_re, p))
print('%.1f confidence interval %.1f%% and %.1f%%' % (alpha*100, lower*100, upper*100))

# plot scores
pyplot.hist(stats2_re)
plt.axvline(x=lower, color='green', linestyle='--')
plt.axvline(x=upper, color='green', linestyle='--')
pyplot.show()
# Out:
# 95.0 confidence interval 20.9% and 27.8%

# %%
(20.9+27.8)/2
# Out:
# 24.35

# %%
(31.3-24.35)/31.3 # percentage change on avg of bootstrap confidence interval month zero and month1
# Out:
# 0.22204472843450476

# %% [markdown]
# that mean we have got event rate on month1 to process the month1 bootstrap confidence interval

# %% [markdown]
# # Sampling bootstrap n sets with LogisticRegression
# use model predict each bootstrap set then find confidence interval

# %%
df_mock_demo.values.shape
# Out:
# (767, 9)

# %%
import numpy
from pandas import read_csv
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from matplotlib import pyplot
from tqdm import tqdm

# load dataset
# data = read_csv('data.csv', header=None)

values = df_mock_demo.values
# train = resample(values, n_samples=n_size)
# test = numpy.array([x for x in values if x.tolist() not in train.tolist()])

# configure bootstrap
n_iterations = 1000
n_size = int(len(df_mock_demo) * 0.50)

# fit model
model = LogisticRegression(random_state=0)
model.fit(values[:,:-1], values[:,-1])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
# run bootstrap
stats3 = list()
for i in tqdm(range(n_iterations)):
	# prepare train and test sets
	train = resample(values, n_samples=n_size)
	test = numpy.array([x for x in values if x.tolist() not in train.tolist()])

	# evaluate model
	predictions = model.predict(test[:,:-1])
	score = accuracy_score(test[:,-1], predictions)
	# print(score)
	stats3.append(score)
# Out:
# 100%|██████████| 1000/1000 [01:57<00:00,  8.51it/s]

# %% [markdown]
# confidence interval

# %%
# confidence intervals
alpha = 0.95
p = ((1.0-alpha)/2.0) * 100
lower = max(0.0, numpy.percentile(stats3, p))
p = (alpha+((1.0-alpha)/2.0)) * 100
upper = min(1.0, numpy.percentile(stats3, p))
print('%.1f confidence interval %.1f%% and %.1f%%' % (alpha*100, lower*100, upper*100))

# plot scores
pyplot.hist(stats3)
plt.axvline(x=lower, color='green', linestyle='--')
plt.axvline(x=upper, color='green', linestyle='--')
plt.axvline(x=(lower+upper)/2, color='red', linestyle='-')
pyplot.show()
# Out:
# 95.0 confidence interval 75.3% and 80.3%

# %% [markdown]
# # Sampling bootstrap n sets with GradientBoostingClassifier
# use model predict each bootstrap set then find confidence interval

# %%
from sklearn.ensemble import GradientBoostingClassifier


values = df_mock_demo.values

# configure bootstrap
n_iterations = 1000
n_size = int(len(df_mock_demo) * 0.50)

# fit model
model = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
max_depth=1, random_state=0).fit(values[:,:-1], values[:,-1])

# %%
# run bootstrap
stats4 = list()
for i in tqdm(range(n_iterations)):
	# prepare train and test sets
	train = resample(values, n_samples=n_size)
	test = numpy.array([x for x in values if x.tolist() not in train.tolist()])

	# evaluate model
	predictions = model.predict(test[:,:-1])
	score = accuracy_score(test[:,-1], predictions)
	# print(score)
	stats4.append(score)
# Out:
# 100%|██████████| 1000/1000 [01:51<00:00,  8.96it/s]

# %%
# confidence intervals
alpha = 0.95
p = ((1.0-alpha)/2.0) * 100
lower = max(0.0, numpy.percentile(stats4, p))
p = (alpha+((1.0-alpha)/2.0)) * 100
upper = min(1.0, numpy.percentile(stats4, p))
print('%.1f confidence interval %.1f%% and %.1f%%' % (alpha*100, lower*100, upper*100))

# plot scores
pyplot.hist(stats4)
plt.axvline(x=lower, color='green', linestyle='--')
plt.axvline(x=upper, color='green', linestyle='--')
plt.axvline(x=(lower+upper)/2, color='red', linestyle='-')

pyplot.show()
# Out:
# 95.0 confidence interval 82.9% and 87.1%
