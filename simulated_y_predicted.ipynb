# %% [markdown]
# # simulate y (label/ actual / event zero) failed

# %%
np.random.seed(42)
random_numbers = np.random.random(size=1000000)
# random_numbers

# %%
plt.hist(random_numbers, bins=10)
# Out:
# (array([ 99829.,  99547., 100144., 100097.,  99864.,  99993., 100315.,
#          99958., 100284.,  99969.]),
#  array([5.18844567e-07, 1.00000298e-01, 2.00000078e-01, 2.99999858e-01,
#         3.99999637e-01, 4.99999417e-01, 5.99999196e-01, 6.99998976e-01,
#         7.99998756e-01, 8.99998535e-01, 9.99998315e-01]),
#  <BarContainer object of 10 artists>)

# %%
rs = np.random.RandomState(5)

GT = rs.normal(size = 1000) # groud truth month zero (y)
# month0_yhat = rs.normal(loc = 0.1, size = 1000)
# month1_yhat = rs.normal(loc = 0.3, size = 1000)

# %%
plt.hist(GT, bins=10)
# Out:
# (array([  5.,  18.,  74., 193., 258., 249., 147.,  38.,  14.,   4.]),
#  array([-3.28391545, -2.59429205, -1.90466866, -1.21504526, -0.52542186,
#          0.16420153,  0.85382493,  1.54344832,  2.23307172,  2.92269512,
#          3.61231851]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # simulate y (label/ actual / event zero) OK normal distribution

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# from psi import calculate_psi

# %%
import random

import scipy.stats
lower = 0
upper = 1
mu = 0.5
sigma = 0.1
N = 10000

samples = scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)
samples
# Out:
# array([0.60415309, 0.55880395, 0.54369785, ..., 0.46770975, 0.70478079,
#        0.45095364])

# %%
plt.hist(samples, bins=100)
# Out:
# (array([  2.,   0.,   3.,   3.,   2.,   2.,   4.,   3.,   3.,   8.,   6.,
#           7.,   8.,  11.,  10.,  19.,  17.,  17.,  28.,  29.,  34.,  42.,
#          42.,  52.,  69.,  60.,  67.,  78.,  98., 101.,  95., 140., 169.,
#         165., 132., 165., 175., 183., 184., 196., 234., 229., 241., 237.,
#         282., 298., 231., 289., 256., 311., 279., 257., 275., 260., 290.,
#         253., 239., 229., 241., 214., 213., 186., 219., 185., 172., 172.,
#         125., 125., 119., 109.,  95.,  94.,  84.,  80.,  65.,  48.,  58.,
#          37.,  47.,  37.,  30.,  18.,  16.,  14.,   9.,  12.,  14.,  12.,
#           7.,   8.,   5.,   3.,   2.,   2.,   1.,   0.,   0.,   1.,   0.,
#           2.]),
#  array([0.15497737, 0.16191637, 0.16885538, 0.17579438, 0.18273339,
#         0.18967239, 0.1966114 , 0.20355041, 0.21048941, 0.21742842,
#         0.22436742, 0.23130643, 0.23824543, 0.24518444, 0.25212345,
#         0.25906245, 0.26600146, 0.27294046, 0.27987947, 0.28681847,
# ...

# %% [markdown]
# ## simulate set label, actual/ event zero and save to csv to use

# %% [markdown]
# ### Y actual (label)
# --can not mock up

# %% [markdown]
# ### Y predcited (month zero/deploy)

# %%
y_predicted_m0 = samples.copy()
y_predicted_m0[:20]
# Out:
# array([0.60415309, 0.55880395, 0.54369785, ..., 0.46770975, 0.70478079,
#        0.45095364])

# %%
y_predicted_m0[:20]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-79ec91eba370> in <cell line: 1>()
# ----> 1 y_predicted_m0[:20]
#
# NameError: name 'y_predicted_m0' is not defined

# %%
df = pd.DataFrame(y_predicted_m0)
df
# Out:
#              0
# 0     0.604153
# 1     0.558804
# 2     0.543698
# 3     0.598509
# 4     0.449717
# ...        ...
# 9995  0.590711
# 9996  0.463972
# 9997  0.467710
# 9998  0.704781
# 9999  0.450954
#
# [10000 rows x 1 columns]

# %%
df.to_csv("mock_y_pred_m0.csv")

# %%
#/content/drive/MyDrive/com7_cradit_scoring/Ai monitoring

# %%
df.to_csv("/content/drive/MyDrive/com7_cradit_scoring/Ai monitoring/mock_y_pred_m0.csv")

# %% [markdown]
# # simulate y predicted month 2

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# from psi import calculate_psi

# %%
import random

import scipy.stats
lower = 0
upper = 1
mu = 0.6
sigma = 0.1
N = 10000

samples2 = scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)
samples2
# Out:
# array([0.55763016, 0.50900979, 0.56575917, ..., 0.71138501, 0.55034663,
#        0.51097831])

# %%
plt.hist(samples2, bins=100)
# Out:
# (array([  1.,   0.,   1.,   0.,   0.,   0.,   1.,   0.,   0.,   1.,   0.,
#           1.,   2.,   2.,   5.,   1.,   4.,   3.,   6.,   7.,  15.,  18.,
#          12.,  21.,  14.,  20.,  28.,  37.,  28.,  42.,  40.,  60.,  68.,
#          66.,  82., 120., 125., 121., 119., 149., 163., 196., 180., 197.,
#         215., 257., 232., 289., 302., 276., 275., 267., 332., 303., 330.,
#         346., 338., 290., 277., 286., 278., 275., 291., 239., 248., 257.,
#         192., 184., 197., 151., 146., 123., 111., 116.,  88.,  77.,  69.,
#          65.,  41.,  56.,  36.,  28.,  39.,  21.,  12.,  19.,  11.,  10.,
#           4.,   7.,   5.,   9.,   8.,   6.,   3.,   1.,   1.,   2.,   0.,
#           3.]),
#  array([0.16807106, 0.17593078, 0.18379049, 0.19165021, 0.19950992,
#         0.20736964, 0.21522935, 0.22308907, 0.23094878, 0.2388085 ,
#         0.24666821, 0.25452793, 0.26238764, 0.27024736, 0.27810707,
#         0.28596679, 0.2938265 , 0.30168622, 0.30954593, 0.31740565,
# ...

# %%
y_predicted_m1 = samples2.copy()
df = pd.DataFrame(y_predicted_m1)

# %%
df.to_csv("/content/drive/MyDrive/com7_cradit_scoring/Ai monitoring/mock_y_pred_m2.csv")

# %% [markdown]
# # simulate y predicted month 1

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# from psi import calculate_psi

# %%
import random

import scipy.stats
lower = 0
upper = 1
mu = 0.38
sigma = 0.1
N = 10000

samples2 = scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)
samples2
# Out:
# array([0.44160641, 0.43191806, 0.41776694, ..., 0.33904789, 0.34948917,
#        0.39323811])

# %%
plt.hist(samples2, bins=100)
# Out:
# (array([  1.,   1.,   1.,   0.,   0.,   1.,   4.,   3.,   3.,   5.,   9.,
#           4.,   5.,   5.,  11.,  10.,  14.,  22.,  18.,  27.,  30.,  29.,
#          44.,  47.,  51.,  63.,  84.,  84.,  97., 105., 124., 144., 167.,
#         161., 169., 188., 211., 204., 235., 257., 254., 258., 272., 283.,
#         328., 300., 327., 296., 278., 309., 349., 297., 283., 266., 295.,
#         267., 262., 240., 225., 224., 188., 172., 173., 144., 129., 108.,
#         115.,  98.,  95.,  75.,  74.,  69.,  59.,  39.,  31.,  35.,  28.,
#          20.,  16.,  17.,   8.,  12.,   6.,   9.,   4.,   4.,   6.,   5.,
#           3.,   2.,   2.,   1.,   1.,   0.,   0.,   0.,   0.,   0.,   0.,
#           1.]),
#  array([0.00259623, 0.01043254, 0.01826885, 0.02610516, 0.03394147,
#         0.04177778, 0.04961409, 0.0574504 , 0.06528671, 0.07312303,
#         0.08095934, 0.08879565, 0.09663196, 0.10446827, 0.11230458,
#         0.12014089, 0.1279772 , 0.13581351, 0.14364982, 0.15148613,
# ...

# %%
y_predicted_m1 = samples2.copy()
df = pd.DataFrame(y_predicted_m1)

# %%
df.to_csv("/content/drive/MyDrive/com7_cradit_scoring/Ai monitoring/mock_y_pred_m1.csv")

# %% [markdown]
# # simulate y predicted month 0 mean 0.3

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# from psi import calculate_psi

# %%
import random

import scipy.stats
lower = 0
upper = 1
mu = 0.3
sigma = 0.1
kurt = -0.6
N = 10000

samples0 = scipy.stats.truncnorm.rvs(
          (lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N)
samples0
# Out:
# array([0.38957879, 0.34509685, 0.35543495, ..., 0.3680238 , 0.50728944,
#        0.4430572 ])

# %%
plt.hist(samples0, bins=100)
# Out:
# (array([ 10.,   6.,   5.,   4.,   2.,   6.,   8.,   6.,  14.,  19.,  16.,
#          16.,  22.,  26.,  34.,  31.,  43.,  60.,  70.,  81.,  81.,  74.,
#          95., 106., 102., 109., 129., 134., 153., 152., 191., 165., 200.,
#         223., 251., 231., 246., 244., 271., 267., 268., 261., 287., 291.,
#         290., 290., 296., 272., 269., 258., 251., 231., 224., 189., 218.,
#         202., 183., 191., 156., 139., 153., 126., 109., 107., 100.,  89.,
#          65.,  84.,  61.,  66.,  58.,  39.,  33.,  31.,  34.,  27.,  23.,
#          16.,  18.,  15.,  12.,   9.,  14.,   4.,  11.,   5.,   4.,   4.,
#           2.,   1.,   2.,   1.,   1.,   2.,   1.,   0.,   0.,   0.,   2.,
#           2.]),
#  array([0.00090348, 0.00774774, 0.014592  , 0.02143626, 0.02828052,
#         0.03512477, 0.04196903, 0.04881329, 0.05565755, 0.06250181,
#         0.06934607, 0.07619033, 0.08303459, 0.08987885, 0.09672311,
#         0.10356737, 0.11041162, 0.11725588, 0.12410014, 0.1309444 ,
# ...

# %%
y_predicted_mZero = samples0.copy()
df = pd.DataFrame(y_predicted_mZero)

# %%
df.to_csv("/content/drive/MyDrive/com7_cradit_scoring/Ai monitoring/mock_y_pred_mZero.csv")
