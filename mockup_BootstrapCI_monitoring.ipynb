# %% [markdown]
# # import lib drive and load data mock up

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
df0 = pd.read_csv("/content/drive/MyDrive/com7_cradit_scoring/Ai monitoring/mock_y_pred_mZero.csv")
df1 = pd.read_csv("/content/drive/MyDrive/com7_cradit_scoring/Ai monitoring/mock_y_pred_m1.csv")
df2 = pd.read_csv("/content/drive/MyDrive/com7_cradit_scoring/Ai monitoring/mock_y_pred_m2.csv")
df_mock_demo = pd.read_csv("/content/drive/MyDrive/com7_cradit_scoring/Ai monitoring/demo_classification_mock.data.csv")

# %%
df2["0"].head()
# Out:
# 0    0.557630
# 1    0.509010
# 2    0.565759
# 3    0.647003
# 4    0.628223
# Name: 0, dtype: float64

# %%
df0.drop('Unnamed: 0', axis=1, inplace = np.True_)
df1.drop('Unnamed: 0', axis=1, inplace = np.True_)
df2.drop('Unnamed: 0', axis=1, inplace = np.True_)

# %%
df0 # month zero (deployment month)
# Out:
#              0
# 0     0.389579
# 1     0.345097
# 2     0.355435
# 3     0.353843
# 4     0.255176
# ...        ...
# 9995  0.129192
# 9996  0.444158
# 9997  0.368024
# 9998  0.507289
# 9999  0.443057
#
# [10000 rows x 1 columns]

# %% [markdown]
# # Confident interval with month zero (refference deployment month)

# %%
# import scipy.stats as st

# %%
df0['0']
# Out:
# 0       0.389579
# 1       0.345097
# 2       0.355435
# 3       0.353843
# 4       0.255176
#           ...
# 9995    0.129192
# 9996    0.444158
# 9997    0.368024
# 9998    0.507289
# 9999    0.443057
# Name: 0, Length: 10000, dtype: float64

# %%
data  = list(df0['0'])

# create 95% confidence interval
low_bon = np.quantile(data, 0.025)
high_bon = np.quantile(data, 0.975)
print("95% interval from {} to {}".format(low_bon,high_bon))
# Out:
# 95% interval from 0.11406714178877335 to 0.49752131663964155

# %%
low_bon/high_bon
# Out:
# 0.2292708633254262

# %%
plt.hist(data, bins=100)
plt.axvline(x=low_bon, color='green', linestyle=':')
plt.axvline(x=high_bon, color='green', linestyle=':')

# %% [markdown]
# # M0 (self) Bootstrap Confident interval at y only
# Next, we will configure the bootstrap. We will use 1,000 bootstrap iterations and select a sample that is 50% the size of the dataset.
#
# modified from method done in x feature

# %%
# import numpy
# from pandas import read_csv
# from sklearn.utils import resample
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.metrics import accuracy_score
# from matplotlib import pyplot
# # load dataset
# data = read_csv('pima-indians-diabetes.data.csv', header=None)
# values = data.values
# # configure bootstrap
# n_iterations = 1000
# n_size = int(len(data) * 0.50)
# # run bootstrap
# stats = list()
# for i in range(n_iterations):
# 	# prepare train and test sets
# 	train = resample(values, n_samples=n_size)
# 	test = numpy.array([x for x in values if x.tolist() not in train.tolist()])
# 	# fit model
# 	model = DecisionTreeClassifier()
# 	model.fit(train[:,:-1], train[:,-1])
# 	# evaluate model
# 	predictions = model.predict(test[:,:-1])
# 	score = accuracy_score(test[:,-1], predictions)
# 	print(score)
# 	stats.append(score)
# # plot scores
# pyplot.hist(stats)
# pyplot.show()
# # confidence intervals
# alpha = 0.95
# p = ((1.0-alpha)/2.0) * 100
# lower = max(0.0, numpy.percentile(stats, p))
# p = (alpha+((1.0-alpha)/2.0)) * 100
# upper = min(1.0, numpy.percentile(stats, p))
# print('%.1f confidence interval %.1f%% and %.1f%%' % (alpha*100, lower*100, upper*100))

# %%
# configure bootstrap

n_iterations = 1000
n_size = int(len(data) * 0.50)

# %%
n_size
# Out:
# 5000

# %%
len(data)
# Out:
# 10000

# %%
# run bootstrap
# y_proba_stats = list()

for i in range(n_iterations):
	# prepare train and test sets
	train = resample(values, n_samples=n_size)
# Out:
# 0       0.389579
# 1       0.345097
# 2       0.355435
# 3       0.353843
# 4       0.255176
#           ...
# 9995    0.129192
# 9996    0.444158
# 9997    0.368024
# 9998    0.507289
# 9999    0.443057
# Name: 0, Length: 10000, dtype: float64

# %%
current_values = [0.6, 0.7, 0.6, 0.6, 0.75] # month 1st???? ---- current month
current_values = df0['0'][:10000]

# %%
history_acc = calculate_relative_accuracy_percentage(refference_values, current_values)
history_acc

# %%
acceptable_accuracy_threshold = 0.30
print("average y_proba on current month", np.mean(current_values))

plt.plot(history_acc)
plt.axhline(y=acceptable_accuracy_threshold, color='r', linestyle='-')
plt.axhline(y=np.mean(current_values), color='green', linestyle='--')
plt.ylabel("relative_accuracy_percentage")
plt.xlabel("individual proba each person")
plt.show()
# Out:
# average y_proba on current month 0.3023794686565615

# %% [markdown]
# # from dataset

# %%
df_mock_demo.values.shape
# Out:
# (767, 9)

# %%
int(len(df_mock_demo)*0.5)
# Out:
# 383

# %%
resample(df_mock_demo.values, n_samples=383).shape
# Out:
# (383, 9)

# %%
numpy.array([x for x in df_mock_demo.values]).shape
# Out:
# (767, 9)

# %%
import numpy
from pandas import read_csv
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from matplotlib import pyplot
# load dataset
# data = read_csv('data.csv', header=None)

values = df_mock_demo.values
# configure bootstrap
n_iterations = 1000
n_size = int(len(df_mock_demo) * 0.50)
# run bootstrap
stats = list()
for i in range(n_iterations):
	# prepare train and test sets
	train = resample(values, n_samples=n_size)
	test = numpy.array([x for x in values if x.tolist() not in train.tolist()])
	# fit model
	model = DecisionTreeClassifier()
	model.fit(train[:,:-1], train[:,-1])
	# evaluate model
	predictions = model.predict(test[:,:-1])
	score = accuracy_score(test[:,-1], predictions)
	print(score)
	stats.append(score)

# %% [markdown]
# here we can **change score to do bootstrap to be other metric** apart from accurcy such as F1 score , or recal, or AUC

# %% [markdown]
# When we got Month 1 and event rate on month 1 we also can compare Confident interval and define threshold to decide for recalibrate or redevelop as well

# %%
len(stats) # list
# Out:
# 1000

# %%
stats1 = [1-x for x in stats ]
stats1
# Out:
# [0.31739130434782614,
#  0.28293736501079914,
#  0.32548179871520344,
#  0.35924369747899154,
#  0.34754797441364604,
#  0.2603938730853391,
#  0.32548179871520344,
#  0.35220125786163525,
#  0.28907922912205564,
#  0.2704402515723271,
#  0.326271186440678,
#  0.3081896551724138,
#  0.2989247311827957,
#  0.3162393162393162,
#  0.3254310344827587,
#  0.31063829787234043,
#  0.3131749460043196,
#  0.26521739130434785,
#  0.3568376068376068,
#  0.33615221987315014,
#  0.3484848484848485,
#  0.32548179871520344,
#  0.3006396588486141,
#  0.29978118161925604,
#  0.2947598253275109,
#  0.34042553191489366,
#  0.28025477707006374,
#  0.32478632478632474,
#  0.28210526315789475,
#  0.27521008403361347,
#  0.32978723404255317,
#  0.3304904051172708,
#  0.3190578158458244,
#  0.30043859649122806,
#  0.30952380952380953,
#  0.3204301075268817,
#  0.30590717299578063,
#  0.3246753246753247,
#  0.30501089324618735,
#  0.298728813559322,
#  0.30196936542669583,
#  0.3231441048034934,
# ...

# %% [markdown]
# ## month0 bootstrap confidence interval

# %%
# confidence intervals
alpha = 0.95
p = ((1.0-alpha)/2.0) * 100
lower = max(0.0, numpy.percentile(stats1, p))
p = (alpha+((1.0-alpha)/2.0)) * 100
upper = min(1.0, numpy.percentile(stats1, p))
print('%.1f confidence interval %.1f%% and %.1f%%' % (alpha*100, lower*100, upper*100))

# plot scores
pyplot.hist(stats1)
plt.axvline(x=lower, color='green', linestyle='--')
plt.axvline(x=upper, color='green', linestyle='--')
pyplot.show()
# Out:
# 95.0 confidence interval 27.0% and 35.6%

# %%
(27+35.6)/2
# Out:
# 31.3

# %% [markdown]
# # trial fuction sim drift dataset
# bootstrap have to train and see at score from iteration bootstrapping.
# <br>The idea is :<br>
# So we simulate just assume that we use same model but actually use little bit bad model to simulate drifting on prediction

# %%
import numpy
from pandas import read_csv
from sklearn.utils import resample
# from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from matplotlib import pyplot
# load dataset
# data = read_csv('data.csv', header=None)

values = df_mock_demo.values
# configure bootstrap
n_iterations = 1000
n_size = int(len(df_mock_demo) * 0.50)
# run bootstrap
stats2 = list()
for i in range(n_iterations):
	# prepare train and test sets
	train = resample(values, n_samples=n_size)
	test = numpy.array([x for x in values if x.tolist() not in train.tolist()])
	# fit model
	model = LogisticRegression(random_state=0)
	model.fit(train[:,:-1], train[:,-1])
	# evaluate model
	predictions = model.predict(test[:,:-1])
	score = accuracy_score(test[:,-1], predictions)
	print(score)
	stats2.append(score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
stats2_re = [1-x for x in stats2 ]

# %%
stats2_re
# Out:
# [0.24463519313304716,
#  0.25,
#  0.2217484008528785,
#  0.21961620469083154,
#  0.225531914893617,
#  0.2468619246861925,
#  0.21444201312910283,
#  0.2717622080679406,
#  0.22795698924731178,
#  0.23529411764705888,
#  0.24836601307189543,
#  0.24197002141327628,
#  0.2367864693446089,
#  0.23861171366594358,
#  0.266384778012685,
#  0.25110132158590304,
#  0.2559139784946236,
#  0.2547770700636943,
#  0.2575107296137339,
#  0.23404255319148937,
#  0.24789915966386555,
#  0.23632385120350108,
#  0.22489082969432317,
#  0.2174840085287847,
#  0.2603036876355749,
#  0.24353448275862066,
#  0.22103004291845496,
#  0.24893617021276593,
#  0.240506329113924,
#  0.2349137931034483,
#  0.2627118644067796,
#  0.267223382045929,
#  0.24507658643326036,
#  0.22505307855626322,
#  0.21814254859611226,
#  0.2098501070663812,
#  0.23706896551724133,
#  0.23880597014925375,
#  0.21684210526315795,
#  0.25,
#  0.22052401746724892,
#  0.2267818574514039,
#  0.2494802494802495,
# ...

# %% [markdown]
# ## month1 bootstrap confidence interval

# %%
# confidence intervals
alpha = 0.95
p = ((1.0-alpha)/2.0) * 100
lower = max(0.0, numpy.percentile(stats2_re, p))
p = (alpha+((1.0-alpha)/2.0)) * 100
upper = min(1.0, numpy.percentile(stats2_re, p))
print('%.1f confidence interval %.1f%% and %.1f%%' % (alpha*100, lower*100, upper*100))

# plot scores
pyplot.hist(stats2_re)
plt.axvline(x=lower, color='green', linestyle='--')
plt.axvline(x=upper, color='green', linestyle='--')
pyplot.show()
# Out:
# 95.0 confidence interval 20.9% and 27.8%

# %%
(20.9+27.8)/2
# Out:
# 24.35

# %%
(31.3-24.35)/31.3 # percentage change on avg of bootstrap confidence interval month zero and month1
# Out:
# 0.22204472843450476

# %% [markdown]
# that mean we have got event rate on month1 to process the month1 bootstrap confidence interval
